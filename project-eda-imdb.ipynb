# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a serious of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer: 
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# #### Check the data type of each column.

# %%
# Answer:
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:
movies['duration'].mean()
# Out:
# 120.97957099080695

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:
movies.sort_values('duration')
# Out:
#      star_rating                                          title  \
# 389          8.0                                         Freaks
# 338          8.0                            Battleship Potemkin
# 258          8.1                    The Cabinet of Dr. Caligari
# 293          8.1                                      Duck Soup
# 88           8.4                                        The Kid
# 742          7.6                                      Following
# 351          8.0                                   Frankenstein
# 938          7.4                            Alice in Wonderland
# 405          7.9                      The Bride of Frankenstein
# 303          8.0                 The Nightmare Before Christmas
# 713          7.6                                The Jungle Book
# 864          7.5                                          [Rec]
# 489          7.8                     The Triplets of Belleville
# 535          7.8                                          Zelig
# ...

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
# Answer:
movies['duration'].plot(kind='hist', bins=20);

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
# Answer:
movies['duration'].plot(kind='box');

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
# Answer:
movies[['content_rating','title']].groupby('content_rating').count()
# Out:
#                 title
# content_rating
# APPROVED           47
# G                  32
# GP                  3
# NC-17               7
# NOT RATED          65
# PASSED              7
# PG                123
# PG-13             189
# R                 460
# TV-MA               1
# UNRATED            38
# X                   4

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
# Answer:
movies[['content_rating','title']].groupby('content_rating').count().plot(kind='barh', title='Content Rating vs Title Count', color='G')
plt.xlabel('Content Rating')
plt.ylabel('Title Count')
# Out:
# C:\Users\dnava\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1298: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   return ax.barh(x, y, w, left=start, log=log, **kwds)
# Text(0, 0.5, 'Title Count')

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
# Answer:
movies['content_rating'].replace(['NOT RATED','APPROVED','PASSED','GP'],'UNRATED')
# Out:
# 0            R
# 1            R
# 2            R
# 3        PG-13
# 4            R
# 5      UNRATED
# 6      UNRATED
# 7        PG-13
# 8            R
# 9            R
# 10       PG-13
# 11       PG-13
# 12          PG
# 13       PG-13
# 14       PG-13
# 15       PG-13
# 16           R
# 17     UNRATED
# 18           R
# 19          PG
# 20           R
# 21           R
# 22     UNRATED
# 23           R
# 24           R
# 25       PG-13
# 26       PG-13
# 27           R
# 28           R
# 29     UNRATED
#         ...
# 949         PG
# 950          R
# 951          R
# 952          R
# 953         PG
# 954      PG-13
# 955          R
# 956         PG
# 957          R
# 958      PG-13
# 959          R
# 960      PG-13
# 961          R
# 962         PG
# 963          R
# 964      PG-13
# 965      PG-13
# 966      PG-13
# 967          R
# 968          R
# 969          R
# 970          R
# 971          R
# 972      NC-17
# 973      PG-13
# 974         PG
# 975         PG
# 976      PG-13
# ...

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:
movies['content_rating'].replace(['X','TV-MA'],'NC-17')
# Out:
# 0              R
# 1              R
# 2              R
# 3          PG-13
# 4              R
# 5      NOT RATED
# 6      NOT RATED
# 7          PG-13
# 8              R
# 9              R
# 10         PG-13
# 11         PG-13
# 12            PG
# 13         PG-13
# 14         PG-13
# 15         PG-13
# 16             R
# 17       UNRATED
# 18             R
# 19            PG
# 20             R
# 21             R
# 22      APPROVED
# 23             R
# 24             R
# 25         PG-13
# 26         PG-13
# 27             R
# 28             R
# 29        PASSED
#          ...
# 949           PG
# 950            R
# 951            R
# 952            R
# 953           PG
# 954        PG-13
# 955            R
# 956           PG
# 957            R
# 958        PG-13
# 959            R
# 960        PG-13
# 961            R
# 962           PG
# 963            R
# 964        PG-13
# 965        PG-13
# 966        PG-13
# 967            R
# 968            R
# 969            R
# ...

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer:
movies.isnull().sum(axis=0)
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
movies.head(950)
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:
movies[movies['content_rating'].isnull()]
movies.at[(187,649),'content_rating'] = 'PG'
movies.at[936,'content_rating'] = 'PG-13'

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
# Answer:
print('Avg. star rating for movies 2 hours or longer: ', movies[movies['duration'] >= 120]['star_rating'].mean(), 
 '\nAvg. star rating for movies shorter than 2 hours: ', movies[movies['duration'] < 120]['star_rating'].mean())
# Out:
# Avg. star rating for movies 2 hours or longer:  7.948898678414082
# Avg. star rating for movies shorter than 2 hours:  7.838666666666657

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:
movies.boxplot(column='duration', by='star_rating', figsize=(10,5));

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
# Answer:
movies[['duration','genre']].groupby('genre').mean()
# Out:
#              duration
# genre
# Action     126.485294
# Adventure  134.840000
# Animation   96.596774
# Biography  131.844156
# Comedy     107.602564
# Crime      122.298387
# Drama      126.539568
# Family     107.500000
# Fantasy    112.000000
# Film-Noir   97.333333
# History     66.000000
# Horror     102.517241
# Mystery    115.625000
# Sci-Fi     109.000000
# Thriller   114.200000
# Western    136.666667

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:
movies.boxplot(column='duration', by='content_rating', figsize=(15,5));
movies.plot(x='content_rating', y='duration'); #terrible, better to use box plot

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
# Answer:
movies.sort_values('star_rating', ascending=False).groupby('genre')['title','star_rating'].first()
#The first() function (convenience method ) is used to subset initial periods of time series data based on a date offset.
# Out:
#                                                    title  star_rating
# genre
# Action                                   The Dark Knight          9.0
# Adventure  The Lord of the Rings: The Return of the King          8.9
# Animation                                  Spirited Away          8.6
# Biography                               Schindler's List          8.9
# Comedy                                      Modern Times          8.6
# Crime                           The Shawshank Redemption          9.3
# Drama                                       12 Angry Men          8.9
# Family                        E.T. the Extra-Terrestrial          7.9
# Fantasy                        The City of Lost Children          7.7
# Film-Noir                                  The Third Man          8.3
# History                              Battleship Potemkin          8.0
# Horror                                            Psycho          8.6
# ...

# %%
movies.sort_values('star_rating', ascending=False).groupby('genre')['title','star_rating'].head()
# Out:
#                                                  title  star_rating
# 0                             The Shawshank Redemption          9.3
# 1                                        The Godfather          9.2
# 2                               The Godfather: Part II          9.1
# 3                                      The Dark Knight          9.0
# 4                                         Pulp Fiction          8.9
# 5                                         12 Angry Men          8.9
# 6                       The Good, the Bad and the Ugly          8.9
# 7        The Lord of the Rings: The Return of the King          8.9
# 8                                     Schindler's List          8.9
# 9                                           Fight Club          8.9
# 13                                        Forrest Gump          8.8
# 14               The Lord of the Rings: The Two Towers          8.8
# 10   The Lord of the Rings: The Fellowship of the Ring          8.8
# ...

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
# Answer:
duplicates = movies[movies['title'].isin(movies[movies.duplicated(['title'])]['title'])]
duplicates.sort_values('title')
# Out:
#      star_rating                            title content_rating      genre  \
# 703          7.6                          Dracula       APPROVED     Horror
# 905          7.5                          Dracula              R     Horror
# 678          7.7                   Les Miserables          PG-13      Drama
# 924          7.5                   Les Miserables          PG-13      Crime
# 466          7.9  The Girl with the Dragon Tattoo              R      Crime
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 662          7.7                        True Grit          PG-13  Adventure
# 936          7.4                        True Grit          PG-13  Adventure
#
#      duration                                        actors_list
# 703        85  [u'Bela Lugosi', u'Helen Chandler', u'David Ma...
# 905       128  [u'Gary Oldman', u'Winona Ryder', u'Anthony Ho...
# 678       158  [u'Hugh Jackman', u'Russell Crowe', u'Anne Hat...
# ...

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %%
#Answer:
avg_star_rating = movies['genre'].value_counts()[movies['genre'].value_counts() > 10].index
movies[movies['genre'].isin(avg_star_rating)].groupby('genre')['star_rating'].mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
# Answer:
movies.genre.value_counts()
relevant_genres=['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Drama','Family','Mystery']
movies[movies.genre.isin(relevant_genres)].groupby('genre').star_rating.mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Family       7.850000
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# Answer:
counts= movies.genre.value_counts()
relevant_genres= counts[counts >=10].index
movies[movies.genre.isin(relevant_genres)].groupby('genre').star_rating.mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:
movies.groupby('genre').star_rating.mean()[movies.genre.value_counts() >= 10]
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:
ratings = movies.groupby('genre').star_rating.agg(['count', 'mean'])
ratings[ratings['count'] >= 10]
# Out:
#            count      mean
# genre
# Action       136  7.884559
# Adventure     75  7.933333
# Animation     62  7.914516
# Biography     77  7.862338
# Comedy       156  7.822436
# Crime        124  7.916935
# Drama        278  7.902518
# Horror        29  7.806897
# Mystery       16  7.975000
